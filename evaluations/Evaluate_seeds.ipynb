# %%
from batchsimevaluations import BatchSimEvaluator

# %%
evaluations = BatchSimEvaluator(input_csv="data/seeds_evaluation_inputs.csv")
tested_variable = "seed"

# %%
evaluations.reports.to_csv("data/seeds_evaluation_outputs.csv", index=False)

# %%
evaluations.plot_metrics(metric_group="proper", tested_variable=tested_variable)

# %%
evaluations.plot_metrics(metric_group="ranking", tested_variable=tested_variable)

# %%
evaluations.plot_metrics(metric_group="points", tested_variable=tested_variable)

# %%
evaluations.plot_run_time(tested_variable=tested_variable)
