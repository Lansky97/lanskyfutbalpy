# %%
from batchsimevaluations import BatchSimEvaluator

# %%
evaluations = BatchSimEvaluator(input_csv="data/ntrials_evaluation_inputs.csv")

# %%
evaluations.reports.to_csv("data/ntrials_evaluation_outputs.csv", index=False)

# %%
evaluations.plot_metrics(metric_group="proper", tested_variable="n_trials")

# %%
evaluations.plot_metrics(metric_group="ranking", tested_variable="n_trials")

# %%
evaluations.plot_metrics(metric_group="points", tested_variable="n_trials")

# %%
evaluations.plot_run_time(tested_variable="n_trials")
